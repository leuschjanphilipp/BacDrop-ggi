# %%
import scanpy as sc
import pandas as pd
import numpy as np
import seaborn as sns
import mudata as md
import networkx as nx
import matplotlib.pyplot as plt

import gc
import sys
sys.path.append('../')

from utils.gglasso_pipeline import gg_lasso_network_analysis
from gglasso.problem import glasso_problem
from utils.utils import calc_sparsity, plot_lambda1_path
from gglasso.helper.basic_linalg import scale_array_by_diagonal
from scipy.cluster.hierarchy import linkage
from latentcor import latentcor

import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# ### KP

# %%
kp_mudata = md.read("../data/preprocessed/kp_mudata_preprocessed.h5mu")
kp_mudata
# Out:
# c:\Users\Jan\.conda\envs\bacdrop\lib\site-packages\mudata\_core\mudata.py:491: UserWarning: Cannot join columns with the same name because var_names are intersecting.
#   warnings.warn(
# MuData object with n_obs × n_vars = 760 × 2884
#   3 modalities
#     all_genes:	760 x 2648
#       obs:	'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#       var:	'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#       uns:	'genes_match', 'protein_match', 'unmatch_genes'
#       layers:	'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'
#     gc1_genes:	755 x 195
#       obs:	'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#       var:	'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#       uns:	'genes_match', 'protein_match', 'unmatch_genes'
#       layers:	'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'
#     gc5_genes:	731 x 41
#       obs:	'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#       var:	'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#       uns:	'genes_match', 'protein_match', 'unmatch_genes'
#       layers:	'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'

# %%
print("Sparsity:\t\t", calc_sparsity(kp_mudata["gc5_genes"].X.A))
print("Mean counts per gene:\t", np.mean(np.sum(kp_mudata["gc5_genes"].X.A, axis=1)))
print("Median counts per gene:\t", np.median(np.sum(kp_mudata["gc5_genes"].X.A, axis=1)))
print("Mean genes per cell: \t", np.mean(np.sum(kp_mudata["gc5_genes"].X.A, axis=0)))
print("Median genes per cell:\t", np.median(np.sum(kp_mudata["gc5_genes"].X.A, axis=0)))
# Out:
# Sparsity:		 0.8927963698241633
# Mean counts per gene:	 5.112175
# Median counts per gene:	 5.0
# Mean genes per cell: 	 91.14634
# Median genes per cell:	 70.0

# %% [markdown]
# ## Datasets

# %%
kp_mrna_gc5 = kp_mudata["gc5_genes"][:, ~kp_mudata["gc5_genes"].var["rRNA"]].copy()
kp_mrna_gc5
# Out:
# AnnData object with n_obs × n_vars = 731 × 18
#     obs: 'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#     var: 'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#     uns: 'genes_match', 'protein_match', 'unmatch_genes'
#     layers: 'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'

# %%
kp_rrna_gc5 = kp_mudata["gc5_genes"][:, kp_mudata["gc5_genes"].var["rRNA"]].copy()
kp_rrna_gc5
# Out:
# AnnData object with n_obs × n_vars = 731 × 23
#     obs: 'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#     var: 'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#     uns: 'genes_match', 'protein_match', 'unmatch_genes'
#     layers: 'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'

# %%
kp_mrna_gc1 = kp_mudata["gc1_genes"][:, ~kp_mudata["gc1_genes"].var["rRNA"]].copy()
kp_mrna_gc1
# Out:
# AnnData object with n_obs × n_vars = 755 × 152
#     obs: 'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#     var: 'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#     uns: 'genes_match', 'protein_match', 'unmatch_genes'
#     layers: 'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'

# %%
kp_rrna_gc1 = kp_mudata["gc1_genes"][:, kp_mudata["gc1_genes"].var["rRNA"]].copy()
kp_rrna_gc1
# Out:
# AnnData object with n_obs × n_vars = 755 × 43
#     obs: 'strains', 'n_genes_by_counts', 'total_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'total_counts_rRNA', 'log1p_total_counts_rRNA', 'pct_counts_rRNA', 'outlier', 'n_counts'
#     var: 'strains', 'matchin_protein', 'protein', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'protein_name', 'rRNA', 'PC_lev0', 'PC_lev1', 'PC_lev2', 'PC_lev3', 'PC_lev4', 'PC_lev5', 'PC_lev6', 'log1p_mean_counts', 'log1p_total_counts', 'n_counts'
#     uns: 'genes_match', 'protein_match', 'unmatch_genes'
#     layers: 'log1p', 'norm_counts', 'raw_counts', 'sqrt_counts'

# %% [markdown]
# ### GC5: latentcor + GGL

# %%
tps = ['tru' for i in range(kp_mrna_gc5.shape[1])]
kp_est_mrna_gc5 = latentcor(kp_mrna_gc5.layers['sqrt_counts'].A, tps=tps, method='approx', use_nearPD=True, nu=0.001, showplot=True)
# Out:
# c:\Users\Jan\.conda\envs\bacdrop\lib\site-packages\statsmodels\stats\correlation_tools.py:90: IterationLimitWarning:
# Maximum iteration reached.
#
#   warnings.warn(iteration_limit_doc, IterationLimitWarning)

# %%
np.save("../data/latent_est/4S/kp_est_gc5.npy", kp_est_mrna_gc5)

# %%
sns.clustermap(kp_est_mrna_gc5['R'], cmap='seismic', figsize=(7, 7), center=0)

# %%
kp_mrna_gc5_link = linkage(y=kp_est_mrna_gc5['R'], method="average", metric="euclidean")

# %%
kp_ggl_gc5 = gg_lasso_network_analysis(N=kp_mrna_gc5.shape[0], estimate=kp_est_mrna_gc5)
kp_ggl_gc5.create_problem(S_col="R", latent=False)
kp_ggl_gc5.model_selection(lambda1_range=np.logspace(0, -6, 200), gamma=0.1)
# Out:
#
# SINGLE GRAPHICAL LASSO PROBLEM
# Regularization parameters:
# {'lambda1': 0.05, 'mu1': None}
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 30 iterations with status: optimal.
# ADMM terminated after 31 iterations with status: optimal.
# ADMM terminated after 31 iterations with status: optimal.
# ADMM terminated after 33 iterations with status: optimal.
# ADMM terminated after 36 iterations with status: optimal.
# ADMM terminated after 38 iterations with status: optimal.
# ADMM terminated after 42 iterations with status: optimal.
# ADMM terminated after 45 iterations with status: optimal.
# ADMM terminated after 50 iterations with status: optimal.
# ADMM terminated after 56 iterations with status: optimal.
# ADMM terminated after 62 iterations with status: optimal.
# ADMM terminated after 68 iterations with status: optimal.
# ADMM terminated after 57 iterations with status: optimal.
# ADMM terminated after 59 iterations with status: optimal.
# ADMM terminated after 62 iterations with status: optimal.
# ADMM terminated after 63 iterations with status: optimal.
# ADMM terminated after 70 iterations with status: optimal.
# ADMM terminated after 74 iterations with status: optimal.
# ADMM terminated after 77 iterations with status: optimal.
# ADMM terminated after 83 iterations with status: optimal.
# ADMM terminated after 89 iterations with status: optimal.
# ADMM terminated after 96 iterations with status: optimal.
# ADMM terminated after 105 iterations with status: optimal.
# ADMM terminated after 112 iterations with status: optimal.
# ADMM terminated after 121 iterations with status: optimal.
# ADMM terminated after 129 iterations with status: optimal.
# ADMM terminated after 142 iterations with status: optimal.
# ADMM terminated after 155 iterations with status: optimal.
# ADMM terminated after 170 iterations with status: optimal.
# ADMM terminated after 107 iterations with status: optimal.
# ADMM terminated after 115 iterations with status: optimal.
# ADMM terminated after 129 iterations with status: optimal.
# ADMM terminated after 140 iterations with status: optimal.
# ADMM terminated after 155 iterations with status: optimal.
# ADMM terminated after 171 iterations with status: optimal.
# ADMM terminated after 191 iterations with status: optimal.
# ADMM terminated after 209 iterations with status: optimal.
# ADMM terminated after 229 iterations with status: optimal.
# ADMM terminated after 249 iterations with status: optimal.
# ADMM terminated after 277 iterations with status: optimal.
# ADMM terminated after 246 iterations with status: optimal.
# ADMM terminated after 185 iterations with status: optimal.
# ADMM terminated after 213 iterations with status: optimal.
# ADMM terminated after 231 iterations with status: optimal.
# ADMM terminated after 241 iterations with status: optimal.
# ADMM terminated after 266 iterations with status: optimal.
# ADMM terminated after 295 iterations with status: optimal.
# ADMM terminated after 327 iterations with status: optimal.
# ADMM terminated after 369 iterations with status: optimal.
# ADMM terminated after 382 iterations with status: optimal.
# ADMM terminated after 394 iterations with status: optimal.
# ADMM terminated after 394 iterations with status: optimal.
# ADMM terminated after 379 iterations with status: optimal.
# ADMM terminated after 343 iterations with status: optimal.
# ADMM terminated after 374 iterations with status: optimal.
# ADMM terminated after 413 iterations with status: optimal.
# ADMM terminated after 448 iterations with status: optimal.
# ADMM terminated after 494 iterations with status: optimal.
# ADMM terminated after 549 iterations with status: optimal.
# ADMM terminated after 612 iterations with status: optimal.
# ADMM terminated after 371 iterations with status: optimal.
# ADMM terminated after 406 iterations with status: optimal.
# ADMM terminated after 450 iterations with status: optimal.
# ADMM terminated after 489 iterations with status: optimal.
# ADMM terminated after 535 iterations with status: optimal.
# ADMM terminated after 595 iterations with status: optimal.
# ADMM terminated after 660 iterations with status: optimal.
# ADMM terminated after 734 iterations with status: optimal.
# ADMM terminated after 797 iterations with status: optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 826 iterations with status: optimal.
# ADMM terminated after 906 iterations with status: optimal.
# ADMM terminated after 997 iterations with status: optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 485 iterations with status: optimal.
# ADMM terminated after 410 iterations with status: optimal.
# ADMM terminated after 344 iterations with status: optimal.
# ADMM terminated after 340 iterations with status: optimal.
# ADMM terminated after 274 iterations with status: optimal.
# ADMM terminated after 237 iterations with status: optimal.
# ADMM terminated after 234 iterations with status: optimal.
# ADMM terminated after 229 iterations with status: optimal.
# ADMM terminated after 213 iterations with status: optimal.
# ADMM terminated after 207 iterations with status: optimal.
# ADMM terminated after 215 iterations with status: optimal.
# ADMM terminated after 209 iterations with status: optimal.
# ADMM terminated after 201 iterations with status: optimal.
# ADMM terminated after 196 iterations with status: optimal.
# ADMM terminated after 178 iterations with status: optimal.
# ADMM terminated after 170 iterations with status: optimal.
# ADMM terminated after 175 iterations with status: optimal.
# ADMM terminated after 142 iterations with status: optimal.
# ADMM terminated after 54 iterations with status: optimal.
# ADMM terminated after 21 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 16 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 16 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 16 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# {'lambda1': 1e-06, 'mu1': 0}

# %%
kp_sol_gc5 = kp_ggl_gc5.P.solution.precision_

# %%
sns.clustermap(kp_sol_gc5, cmap="seismic", col_linkage=kp_mrna_gc5_link, row_linkage=kp_mrna_gc5_link, figsize=(7, 7), center=0)

# %%
P_dict = kp_ggl_gc5.P.__dict__

lambda1 = P_dict["reg_params"]["lambda1"]
lambda1_range = P_dict["modelselect_params"]["lambda1_range"]
sparsity = P_dict["modelselect_stats"]["SP"]
eBIC = P_dict["modelselect_stats"]["BIC"][0.1]

fig, axs = plt.subplots(1, 2, figsize=(13, 5))

sns.lineplot(x=lambda1_range, y=eBIC.squeeze(), ax=axs[0])
axs[0].axvline(x=lambda1, ls="--", color="C3", label=f"selected lambda1={np.round(lambda1, 7)}")
axs[0].set_xscale("log")
axs[0].set_xlabel("lambda")
axs[0].set_ylabel("eBIC")
axs[0].invert_xaxis()
axs[0].legend()

sns.lineplot(x=lambda1_range, y=sparsity.squeeze(), ax=axs[1])
axs[1].axvline(x=lambda1, ls="--", color="C3", label=f"sparsity={sparsity[np.where(lambda1_range == lambda1)[0][0]]}")
axs[1].set_xscale("log")
axs[1].set_xlabel("lambda")
axs[1].set_ylabel("Sparsity")
axs[1].invert_xaxis()
axs[1].legend()
plt.suptitle("Model selection")
plt.show()

# %%
#number of nodes
print("nodes:", kp_sol_gc5.shape[0])
#number of edges
print("edges:", np.count_nonzero(np.triu(kp_sol_gc5, k=1)))
#ebic value
print(eBIC[np.where(lambda1_range == lambda1)[0][0]])
# Out:
# nodes: 18
# edges: 153
# [-17360.52028843]

# %% [markdown]
# ### GC1: latentcor + GGL

# %%
tps = ['tru' for i in range(kp_mrna_gc1.shape[1])]
kp_est_mrna_gc1 = latentcor(kp_mrna_gc1.layers['sqrt_counts'].A, tps=tps, method='approx', use_nearPD=True, nu=0.001, showplot=True)
# Out:
# c:\Users\Jan\.conda\envs\bacdrop\lib\site-packages\statsmodels\stats\correlation_tools.py:90: IterationLimitWarning:
# Maximum iteration reached.
#
#   warnings.warn(iteration_limit_doc, IterationLimitWarning)

# %%
np.save("../data/latent_est/4S/kp_est_gc1_.npy", kp_est_mrna_gc1)

# %%
sns.clustermap(kp_est_mrna_gc1['R'], cmap='seismic', figsize=(7, 7), center=0)

# %%
kp_mrna_gc1_link = linkage(y=kp_est_mrna_gc1['R'], method="average", metric="euclidean")

# %%
kp_ggl_gc1 = gg_lasso_network_analysis(N=kp_mrna_gc1.shape[0], estimate=kp_est_mrna_gc1)
kp_ggl_gc1.create_problem(S_col="R", latent=False)
kp_ggl_gc1.model_selection(lambda1_range=np.logspace(0, -6, 100), gamma=0.1)
# Out:
#
# SINGLE GRAPHICAL LASSO PROBLEM
# Regularization parameters:
# {'lambda1': 0.05, 'mu1': None}
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 14 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 30 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 13 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 40 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 30 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 17 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 34 iterations with status: optimal.
# ADMM terminated after 30 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 52 iterations with status: optimal.
# ADMM terminated after 80 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 52 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 76 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 77 iterations with status: optimal.
# ADMM terminated after 95 iterations with status: optimal.
# ADMM terminated after 92 iterations with status: optimal.
# ADMM terminated after 111 iterations with status: optimal.
# ADMM terminated after 127 iterations with status: optimal.
# ADMM terminated after 135 iterations with status: optimal.
# ADMM terminated after 146 iterations with status: optimal.
# ADMM terminated after 109 iterations with status: optimal.
# ADMM terminated after 105 iterations with status: optimal.
# ADMM terminated after 117 iterations with status: optimal.
# ADMM terminated after 132 iterations with status: optimal.
# ADMM terminated after 135 iterations with status: optimal.
# ADMM terminated after 147 iterations with status: optimal.
# ADMM terminated after 164 iterations with status: optimal.
# ADMM terminated after 186 iterations with status: optimal.
# ADMM terminated after 210 iterations with status: optimal.
# ADMM terminated after 240 iterations with status: optimal.
# ADMM terminated after 269 iterations with status: optimal.
# ADMM terminated after 313 iterations with status: optimal.
# ADMM terminated after 363 iterations with status: optimal.
# ADMM terminated after 397 iterations with status: optimal.
# ADMM terminated after 405 iterations with status: optimal.
# ADMM terminated after 409 iterations with status: optimal.
# ADMM terminated after 439 iterations with status: optimal.
# ADMM terminated after 491 iterations with status: optimal.
# ADMM terminated after 553 iterations with status: optimal.
# ADMM terminated after 629 iterations with status: optimal.
# ADMM terminated after 707 iterations with status: optimal.
# ADMM terminated after 774 iterations with status: optimal.
# ADMM terminated after 693 iterations with status: optimal.
# ADMM terminated after 707 iterations with status: optimal.
# ADMM terminated after 770 iterations with status: optimal.
# ADMM terminated after 848 iterations with status: optimal.
# ADMM terminated after 896 iterations with status: optimal.
# ADMM terminated after 964 iterations with status: optimal.
# ADMM terminated after 990 iterations with status: optimal.
# ADMM terminated after 972 iterations with status: optimal.
# ADMM terminated after 999 iterations with status: optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 983 iterations with status: optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 1000 iterations with status: primal optimal.
# ADMM terminated after 887 iterations with status: optimal.
# ADMM terminated after 864 iterations with status: optimal.
# ADMM terminated after 858 iterations with status: optimal.
# ADMM terminated after 864 iterations with status: optimal.
# ADMM terminated after 858 iterations with status: optimal.
# ADMM terminated after 857 iterations with status: optimal.
# ADMM terminated after 828 iterations with status: optimal.
# ADMM terminated after 624 iterations with status: optimal.
# ADMM terminated after 546 iterations with status: optimal.
# ADMM terminated after 513 iterations with status: optimal.
# ADMM terminated after 470 iterations with status: optimal.
# ADMM terminated after 442 iterations with status: optimal.
# ADMM terminated after 407 iterations with status: optimal.
# ADMM terminated after 372 iterations with status: optimal.
# ADMM terminated after 347 iterations with status: optimal.
# ADMM terminated after 315 iterations with status: optimal.
# ADMM terminated after 284 iterations with status: optimal.
# ADMM terminated after 216 iterations with status: optimal.
# ADMM terminated after 185 iterations with status: optimal.
# ADMM terminated after 174 iterations with status: optimal.
# ADMM terminated after 149 iterations with status: optimal.
# ADMM terminated after 133 iterations with status: optimal.
# ADMM terminated after 121 iterations with status: optimal.
# ADMM terminated after 108 iterations with status: optimal.
# ADMM terminated after 96 iterations with status: optimal.
# ADMM terminated after 87 iterations with status: optimal.
# ADMM terminated after 74 iterations with status: optimal.
# ADMM terminated after 67 iterations with status: optimal.
# ADMM terminated after 59 iterations with status: optimal.
# ADMM terminated after 54 iterations with status: optimal.
# ADMM terminated after 43 iterations with status: optimal.
# ADMM terminated after 42 iterations with status: optimal.
# ADMM terminated after 42 iterations with status: optimal.
# ADMM terminated after 33 iterations with status: optimal.
# ADMM terminated after 33 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# {'lambda1': 7.56463327554629e-05, 'mu1': 0}

# %%
kp_sol_gc1 = kp_ggl_gc1.P.solution.precision_

# %%
sns.clustermap(kp_sol_gc1, cmap="seismic", col_linkage=kp_mrna_gc1_link, row_linkage=kp_mrna_gc1_link, figsize=(10, 10), center=0)

# %%
P_dict = kp_ggl_gc1.P.__dict__

lambda1 = P_dict["reg_params"]["lambda1"]
lambda1_range = P_dict["modelselect_params"]["lambda1_range"]
sparsity = P_dict["modelselect_stats"]["SP"]
eBIC = P_dict["modelselect_stats"]["BIC"][0.1]

fig, axs = plt.subplots(1, 2, figsize=(13, 5))

sns.lineplot(x=lambda1_range, y=eBIC.squeeze(), ax=axs[0])
axs[0].axvline(x=lambda1, ls="--", color="C3", label=f"selected lambda1={np.round(lambda1, 7)}")
axs[0].set_xscale("log")
axs[0].set_xlabel("lambda")
axs[0].set_ylabel("eBIC")
axs[0].invert_xaxis()
axs[0].legend()

sns.lineplot(x=lambda1_range, y=sparsity.squeeze(), ax=axs[1])
axs[1].axvline(x=lambda1, ls="--", color="C3", label=f"sparsity={sparsity[np.where(lambda1_range == lambda1)[0][0]]}")
axs[1].set_xscale("log")
axs[1].set_xlabel("lambda")
axs[1].set_ylabel("Sparsity")
axs[1].invert_xaxis()
axs[1].legend()
plt.suptitle("Model selection")
plt.show()

# %%
#number of nodes
print("nodes:", kp_sol_gc1.shape[0])
#number of edges
print(np.count_nonzero(np.triu(kp_sol_gc1, k=1)))
#ebic value
print(eBIC[np.where(lambda1_range == lambda1)[0][0]])
# Out:
# nodes: 152
# 8895
# [-296780.88778018]

# %% [markdown]
# ### GC1: EMP COV + GGL

# %%
kp_gc1_emp_cov_est = np.cov(kp_mrna_gc1.layers['sqrt_counts'].A.T, bias=True)

# %%
cm = sns.clustermap(scale_array_by_diagonal(kp_gc1_emp_cov_est), cmap='seismic', center=0, figsize=(14, 14), xticklabels=False, yticklabels=False)

# %%
link = linkage(y=scale_array_by_diagonal(kp_gc1_emp_cov_est), method="average", metric="euclidean")

# %%
print(kp_gc1_emp_cov_est.min(), kp_gc1_emp_cov_est.max())
print(scale_array_by_diagonal(kp_gc1_emp_cov_est).min(), scale_array_by_diagonal(kp_gc1_emp_cov_est).max())
# Out:
# -0.016790735291437865 0.281450028708958
# -0.09427184673233964 1.0000000000000002

# %%
kp_ggl_cov_gc1 = gg_lasso_network_analysis(N=kp_mrna_gc1.shape[0], estimate=scale_array_by_diagonal(kp_gc1_emp_cov_est))
kp_ggl_cov_gc1.create_problem(latent=False)
kp_ggl_cov_gc1.model_selection(lambda1_range=np.logspace(0, -6, 100), gamma=0.1)
# Out:
#
# SINGLE GRAPHICAL LASSO PROBLEM
# Regularization parameters:
# {'lambda1': 0.05, 'mu1': None}
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 13 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 22 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 34 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 31 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 42 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 32 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 48 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 28 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 88 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 49 iterations with status: optimal.
# ADMM terminated after 30 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 75 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 46 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 75 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 25 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 72 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 46 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 69 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 26 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 85 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 10 iterations with status: optimal.
# ADMM terminated after 27 iterations with status: optimal.
# ADMM terminated after 43 iterations with status: optimal.
# ADMM terminated after 92 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 67 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 167 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 9 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 188 iterations with status: optimal.
# ADMM terminated after 8 iterations with status: optimal.
# ADMM terminated after 219 iterations with status: optimal.
# ADMM terminated after 175 iterations with status: optimal.
# ADMM terminated after 201 iterations with status: optimal.
# ADMM terminated after 250 iterations with status: optimal.
# ADMM terminated after 274 iterations with status: optimal.
# ADMM terminated after 323 iterations with status: optimal.
# ADMM terminated after 374 iterations with status: optimal.
# ADMM terminated after 440 iterations with status: optimal.
# ADMM terminated after 503 iterations with status: optimal.
# ADMM terminated after 258 iterations with status: optimal.
# ADMM terminated after 238 iterations with status: optimal.
# ADMM terminated after 284 iterations with status: optimal.
# ADMM terminated after 286 iterations with status: optimal.
# ADMM terminated after 300 iterations with status: optimal.
# ADMM terminated after 275 iterations with status: optimal.
# ADMM terminated after 283 iterations with status: optimal.
# ADMM terminated after 314 iterations with status: optimal.
# ADMM terminated after 323 iterations with status: optimal.
# ADMM terminated after 343 iterations with status: optimal.
# ADMM terminated after 354 iterations with status: optimal.
# ADMM terminated after 380 iterations with status: optimal.
# ADMM terminated after 390 iterations with status: optimal.
# ADMM terminated after 404 iterations with status: optimal.
# ADMM terminated after 387 iterations with status: optimal.
# ADMM terminated after 400 iterations with status: optimal.
# ADMM terminated after 428 iterations with status: optimal.
# ADMM terminated after 456 iterations with status: optimal.
# ADMM terminated after 479 iterations with status: optimal.
# ADMM terminated after 491 iterations with status: optimal.
# ADMM terminated after 480 iterations with status: optimal.
# ADMM terminated after 461 iterations with status: optimal.
# ADMM terminated after 453 iterations with status: optimal.
# ADMM terminated after 539 iterations with status: optimal.
# ADMM terminated after 488 iterations with status: optimal.
# ADMM terminated after 471 iterations with status: optimal.
# ADMM terminated after 446 iterations with status: optimal.
# ADMM terminated after 461 iterations with status: optimal.
# ADMM terminated after 464 iterations with status: optimal.
# ADMM terminated after 458 iterations with status: optimal.
# ADMM terminated after 455 iterations with status: optimal.
# ADMM terminated after 304 iterations with status: optimal.
# ADMM terminated after 287 iterations with status: optimal.
# ADMM terminated after 340 iterations with status: optimal.
# ADMM terminated after 317 iterations with status: optimal.
# ADMM terminated after 259 iterations with status: optimal.
# ADMM terminated after 245 iterations with status: optimal.
# ADMM terminated after 229 iterations with status: optimal.
# ADMM terminated after 215 iterations with status: optimal.
# ADMM terminated after 178 iterations with status: optimal.
# ADMM terminated after 176 iterations with status: optimal.
# ADMM terminated after 146 iterations with status: optimal.
# ADMM terminated after 140 iterations with status: optimal.
# ADMM terminated after 109 iterations with status: optimal.
# ADMM terminated after 99 iterations with status: optimal.
# ADMM terminated after 91 iterations with status: optimal.
# ADMM terminated after 85 iterations with status: optimal.
# ADMM terminated after 80 iterations with status: optimal.
# ADMM terminated after 76 iterations with status: optimal.
# ADMM terminated after 66 iterations with status: optimal.
# ADMM terminated after 57 iterations with status: optimal.
# ADMM terminated after 54 iterations with status: optimal.
# ADMM terminated after 52 iterations with status: optimal.
# ADMM terminated after 52 iterations with status: optimal.
# ADMM terminated after 44 iterations with status: optimal.
# ADMM terminated after 38 iterations with status: optimal.
# ADMM terminated after 37 iterations with status: optimal.
# ADMM terminated after 33 iterations with status: optimal.
# ADMM terminated after 29 iterations with status: optimal.
# ADMM terminated after 24 iterations with status: optimal.
# ADMM terminated after 23 iterations with status: optimal.
# ADMM terminated after 21 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 19 iterations with status: optimal.
# ADMM terminated after 20 iterations with status: optimal.
# ADMM terminated after 18 iterations with status: optimal.
# ADMM terminated after 15 iterations with status: optimal.
# ADMM terminated after 15 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 13 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# ADMM terminated after 12 iterations with status: optimal.
# ADMM terminated after 11 iterations with status: optimal.
# {'lambda1': 0.093260334688322, 'mu1': 0}

# %%
kp_sol_cov_gc1 = kp_ggl_cov_gc1.P.solution.precision_

# %%
sns.clustermap(kp_sol_cov_gc1, cmap="seismic", col_linkage=link, row_linkage=link, figsize=(10, 10), center=0)

# %%
P_dict = kp_ggl_cov_gc1.P.__dict__

lambda1 = P_dict["reg_params"]["lambda1"]
lambda1_range = P_dict["modelselect_params"]["lambda1_range"]
sparsity = P_dict["modelselect_stats"]["SP"]
eBIC = P_dict["modelselect_stats"]["BIC"][0.1]

fig, axs = plt.subplots(1, 2, figsize=(13, 5))

sns.lineplot(x=lambda1_range, y=eBIC.squeeze(), ax=axs[0])
axs[0].axvline(x=lambda1, ls="--", color="C3", label=f"selected lambda1={np.round(lambda1, 7)}")
axs[0].set_xscale("log")
axs[0].set_xlabel("lambda")
axs[0].set_ylabel("eBIC")
axs[0].invert_xaxis()
axs[0].legend()

sns.lineplot(x=lambda1_range, y=sparsity.squeeze(), ax=axs[1])
axs[1].axvline(x=lambda1, ls="--", color="C3", label=f"sparsity={sparsity[np.where(lambda1_range == lambda1)[0][0]]}")
axs[1].set_xscale("log")
axs[1].set_xlabel("lambda")
axs[1].set_ylabel("Sparsity")
axs[1].invert_xaxis()
axs[1].legend()
plt.suptitle("Model selection")
plt.show()

# %%
#number of nodes
print("nodes:", kp_sol_cov_gc1.shape[0])
#number of edges
print("edges:", np.count_nonzero(np.triu(kp_sol_cov_gc1, k=1)))
#ebic value
print("eBIC value: ", eBIC[np.where(lambda1_range == lambda1)[0][0]])
# Out:
# nodes: 152
# edges: 410
# eBIC value:  [86660.38583245]

# %%
#TODO network analysis
labels = efm_mrna_gc1.var["protein_name"].values
labels = [label.split("[")[0] for label in labels]
labels[1]
# Out:
# 'WP_001015311.1 MULTISPECIES: IS6-like element IS1216 family transposase '

# %%
labels_prot = [label.split(" ")[0] for label in efm_mrna_gc1.var["protein_name"].values]
labels_prot[1]
# Out:
# 'WP_001015311.1'

# %%
new_indices = cm.dendrogram_row.reordered_ind
efm_sol_gc1_reorder = efm_sol_gc1[new_indices, :]
efm_sol_gc1_reorder = efm_sol_gc1_reorder[:, new_indices]

labels_prot_reorder = [labels_prot[i] for i in new_indices]

# %%
ec_G = nx.Graph()

# Add nodes to the graph
for row in labels_prot_reorder:
    ec_G.add_node(row)

# Add edges to the graph based on the weights
n = efm_sol_gc1.shape[0]
for i in range(n):
    for j in range(i + 1, n):
        weight = efm_sol_gc1_reorder[i, j]
        if weight != 0:
            ec_G.add_edge(labels_prot[i], labels_prot[j], weight=weight)

# Set edge colors based on weight sign
edge_colors = []
edge_widths = []
for edge in ec_G.edges(data=True):
    weight = edge[2]['weight']
    if weight > 0:
        edge_colors.append('red')  # Positive edge
    elif weight < 0:
        edge_colors.append('blue')  # Negative edge
    edge_widths.append(abs(weight)*2)  # Scale width based on weight


# Draw the graph
pos = nx.shell_layout(ec_G)
plt.figure(figsize=(15, 15))
nx.draw(ec_G, pos, with_labels=True, node_size=100, node_color='skyblue', font_size=5, font_weight='bold', 
        edge_color=edge_colors, width=edge_widths)
plt.title('Graph from Precision Matrix')
plt.show()

# %%
for i in labels:
    if i == "None": continue
    if "MULTISPECIES:" in i:
        print(" ".join(i.split(" ")[2:]))
    else:
        print(" ".join(i.split(" ")[1:]))
# Out:
# IS6-like element IS1216 family transposase
# leucine--tRNA ligase
# polysaccharide biosynthesis protein
# accessory gene regulator B family protein
# sensor histidine kinase
# glucosaminidase domain-containing protein
# glucose-6-phosphate dehydrogenase
# DivIVA domain-containing protein
# RNA-binding protein
# cell division protein SepF
# cell division protein FtsZ
# cell division protein FtsA
# cell division protein FtsQ/DivIB
# 16S rRNA (cytosine(1402)-N(4))-methyltransferase RsmH
# DNA repair protein RecN
# GRP family sugar transporter
# type I glutamate--ammonia ligase
# MerR family transcriptional regulator
# phosphopantothenate--cysteine ligase
# ribonuclease J
# zinc metallopeptidase
# TIGR01906 family membrane protein
# ribonuclease Y
# bifunctional UDP-N-acetylglucosamine diphosphorylase/glucosamine-1-phosphate N-acetyltransferase GlmU
# ribose-phosphate diphosphokinase
# primosomal protein N'
# Stp1/IreP family PP2C-type Ser/Thr phosphatase
# Stk1 family PASTA domain-containing Ser/Thr kinase
# NlpC/P60 family protein
# L-lactate dehydrogenase
# transcription-repair coupling factor
# polysaccharide biosynthesis protein
# tRNA lysidine(34) synthetase TilS
# ATP-dependent zinc metalloprotease FtsH
# glutamate--tRNA ligase
# ATP-dependent Clp protease ATP-binding subunit
# MarR family transcriptional regulator
# beta-ketoacyl-ACP synthase III
# acyl carrier protein
# ACP S-malonyltransferase
# 3-oxoacyl-
# beta-ketoacyl-ACP synthase II
# 3-hydroxyacyl-ACP dehydratase FabZ
# acetyl-CoA carboxylase biotin carboxylase subunit
# acetyl-CoA carboxylase, carboxyltransferase subunit beta
# acetyl-CoA carboxylase carboxyl transferase subunit alpha
# nicotinate-nucleotide adenylyltransferase
# class I SAM-dependent methyltransferase
# RNA polymerase recycling motor HelD
# threonine--tRNA ligase
# Fe-S cluster assembly protein SufD
# cysteine desulfurase
# Fe-S cluster assembly protein SufB
# glycine betaine/L-proline ABC transporter ATP-binding protein
# ABC transporter permease/substrate binding protein
# CdaR family protein
# phosphoglucosamine mutase
# ABC transporter ATP-binding protein
# ATP-binding cassette domain-containing protein
# oligopeptide ABC transporter permease
# ABC transporter permease
# oligopeptide ABC transporter substrate-binding protein
# bifunctional glutamate--cysteine ligase GshA/glutathione synthetase GshB
# ribonuclease J
# valine--tRNA ligase
# septation ring formation regulator EzrA
# peptide MFS transporter
# stage 0 sporulation family protein
# DNA-directed RNA polymerase subunit beta'
# type 2 isopentenyl-diphosphate Delta-isomerase
# ATP-dependent chaperone ClpB
# nucleoside 2-deoxyribosyltransferase
# DNA topoisomerase (ATP-hydrolyzing) subunit B
# single-stranded DNA-binding protein
# adenylosuccinate synthase
# ATP-binding cassette domain-containing protein
# ATP-dependent protease ATPase subunit HslU
# Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatB
# ribosome biogenesis GTP-binding protein YihA/YsxC
# transcription termination factor NusA
# glucose-6-phosphate isomerase
# glutamine-hydrolyzing GMP synthase
# preprotein translocase subunit SecY
# adenylate kinase
# translation initiation factor IF-1
# DNA-directed RNA polymerase subunit alpha
# YfhO family protein
# translational GTPase TypA
# cold-shock protein
# asparagine--tRNA ligase
# amino acid permease
# two-component system regulatory protein YycI
# DEAD/DEAH box helicase
# SMC family ATPase
# F0F1 ATP synthase subunit beta
# ATP-dependent Clp protease ATP-binding subunit
# bifunctional (p)ppGpp synthetase/guanosine-3',5'-bis(diphosphate) 3'-pyrophosphohydrolase
# aspartate--tRNA ligase
# pyrimidine-nucleoside phosphorylase
# collagen-binding MSCRAMM adhesin Acm
# DNA translocase FtsK
# methionine--tRNA ligase
# molecular chaperone DnaJ
# cystathionine gamma-synthase
# ribosomal-processing cysteine protease Prp
# mannose/fructose/sorbose PTS transporter subunit IIB
# mannose/fructose/sorbose PTS transporter subunit IIB
# DNA primase
# RNA polymerase sigma factor RpoD
# ATP-dependent RecD-like DNA helicase
# PBP1A family penicillin-binding protein
# dihydrolipoyl dehydrogenase
# phosphate acyltransferase PlsX
# ATP-dependent DNA helicase RecG
# DAK2 domain-containing protein
# NAD(P)/FAD-dependent oxidoreductase
# YfcC family protein
# HU family DNA-binding protein
# elongation factor Tu
# MIP/aquaporin family protein
# chaperonin GroEL
# FtsW/RodA/SpoVE family cell cycle protein
# catabolite control protein A
# GatB/YqeY domain-containing protein
# trigger factor
# amino acid ABC transporter ATP-binding protein
# molecular chaperone DnaK
# F0F1 ATP synthase subunit gamma
# F0F1 ATP synthase subunit alpha
# F0F1 ATP synthase subunit delta
# phosphopyruvate hydratase
# triose-phosphate isomerase
# type I glyceraldehyde-3-phosphate dehydrogenase
# DNA-directed RNA polymerase subunit delta
# V-type ATP synthase subunit B
# translation initiation factor IF-3
# ribosome recycling factor
# UMP kinase
# translation elongation factor Ts
# UDP-glucose--hexose-1-phosphate uridylyltransferase
# asparagine synthase (glutamine-hydrolyzing)
# putative basic amino acid antiporter YfcC
# DNA polymerase III subunit gamma/tau
# class II fructose-bisphosphate aldolase
# serine hydroxymethyltransferase
# cell wall metabolism sensor histidine kinase WalK
# PolC-type DNA polymerase III
# translation initiation factor IF-2
# deoxynucleoside kinase
# elongation factor G
# 2,3-diphosphoglycerate-dependent phosphoglycerate mutase
# ATP-dependent Clp protease ATP-binding subunit ClpX
# D-aspartate ligase
# heat-inducible transcriptional repressor HrcA
# preprotein translocase subunit SecA
# DUF1292 domain-containing protein
# V-type ATP synthase subunit I
# V-type sodium ATP synthase subunit E
# V-type ATPase subunit
# V-type ATP synthase subunit A
# V-type ATP synthase subunit D
# TrkH family potassium uptake protein
# phosphoglycerate kinase
# L-cystine transporter
# diacylglycerol kinase
# tRNA uridine-5-carboxymethylaminomethyl(34) synthesis enzyme MnmG
# HAMP domain-containing sensor histidine kinase
# pyruvate kinase
# phosphoenolpyruvate--protein phosphotransferase
# hemolysin family protein
# LCP family protein
# nucleobase:cation symporter-2 family protein
# CAP-associated domain-containing protein
# transketolase
# Asp23/Gls24 family envelope stress response protein
# DNA-directed RNA polymerase subunit beta
# lysine--tRNA ligase
# alanine--tRNA ligase
# UDP-N-acetylmuramate--L-alanine ligase
# Tex family protein
# amino acid ABC transporter substrate-binding protein/permease
# nucleotide exchange factor GrpE
# glycosyltransferase family 2 protein
# hypothetical protein
# dTDP-glucose 4,6-dehydratase
# DEAD/DEAH box helicase
# isoleucine--tRNA ligase
# chromosome segregation protein SMC
# phenylalanine--tRNA ligase subunit beta
# helicase-exonuclease AddAB subunit AddA
# ribosome biogenesis GTPase Der
# ABC transporter permease subunit
# polyribonucleotide nucleotidyltransferase
# NADP-dependent phosphogluconate dehydrogenase
# dihydrolipoyllysine-residue acetyltransferase
# F0F1 ATP synthase subunit A
# cation-translocating P-type ATPase
# IS30 family transposase
# IS30 family transposase
# LysM peptidoglycan-binding domain-containing protein
# UDP-N-acetylglucosamine 1-carboxyvinyltransferase
# acetyl-CoA carboxylase biotin carboxyl carrier protein
# ribosome biogenesis GTPase YqeH
# penicillin-binding protein 2
# penicillin-binding transpeptidase domain-containing protein
# acyltransferase family protein
# endonuclease MutS2
# DNA repair protein RadA
# class 1b ribonucleoside-diphosphate reductase subunit alpha
# nucleoside hydrolase
# cation-translocating P-type ATPase
# 6-phosphofructokinase
# 16S rRNA (cytosine(967)-C(5))-methyltransferase RsmB
# UDP-N-acetylmuramoyl-tripeptide--D-alanyl-D-alanine ligase
# Asp-tRNA(Asn)/Glu-tRNA(Gln) amidotransferase subunit GatA
# hydroxymethylglutaryl-CoA reductase, degradative
# DNA helicase PcrA
# DNA topoisomerase IV subunit A
# central glycolytic genes regulator
# NAD-dependent epimerase/dehydratase family protein
# DNA gyrase subunit A
# fructose-specific PTS transporter subunit EIIC
# glutamine--fructose-6-phosphate transaminase (isomerizing)
# pyruvate:ferredoxin (flavodoxin) oxidoreductase
# 3-phosphoshikimate 1-carboxyvinyltransferase
# IS256-like element ISEfm2 family transposase
# LTA synthase family protein
# MraY family glycosyltransferase
# cell division site-positioning protein MapZ family protein
# transglycosylase domain-containing protein
# proline--tRNA ligase
# translation elongation factor 4
# IS6-like element IS1216 family transposase
# IS6-like element IS1216 family transposase
# collagen-binding MSCRAMM adhesin Scm
# class I SAM-dependent methyltransferase
# glycine--tRNA ligase subunit beta
# phospho-sugar mutase
# M13-type metalloendopeptidase
# DNA topoisomerase IV subunit B
# rod shape-determining protein MreC
# pyruvate carboxylase

# %%
mapping = pd.read_csv("../data/string/efm/string_mapping_efm.tsv", sep="\t")
mapping
# Out:
#      #queryIndex                            queryItem          stringId  \
# 0              2                 leucine--tRNA ligase  1352.AL014_13845
# 1              3  polysaccharide biosynthesis protein  1352.AL014_02810
# 2              5              sensor histidine kinase  1352.AL014_03180
# 3              7    glucose-6-phosphate dehydrogenase  1352.AL014_08335
# 4              8     DivIVA domain-containing protein  1352.AL014_08345
# ..           ...                                  ...               ...
# 158          237    glycine--tRNA ligase subunit beta  1352.AL014_02680
# 159          238                 phospho-sugar mutase  1352.AL014_02595
# 160          240       DNA topoisomerase IV subunit B  1352.AL014_04900
# 161          241   rod shape-determining protein MreC  1352.AL014_13475
# 162          242                 pyruvate carboxylase  1352.AL014_05345
#
#     preferredName                                         annotation
# 0          leuS_1  leucyl-tRNA synthetase; Derived by automated c...
# 1      AOM15246.1  Polysaccharide biosynthesis protein; Derived b...
# 2          phoR_2  Histidine kinase; Derived by automated computa...
# 3             zwf  Glucose-6-phosphate dehydrogenase; Catalyzes t...
# 4          DivIVA  Cell division protein DivIVA; Derived by autom...
# ..            ...                                                ...
# 158        glyS_1  glycine-tRNA synthetase subunit beta; Derived ...
# 159          Pgm2  Phosphoglucomutase; Catalyzes the interconvers...
# 160          gyrB  DNA gyrase subunit B; Topoisomerase IV is esse...
# 161          mreC  Rod shape-determining protein MreC; Involved i...
# 162          cfiB  Pyruvate carboxylase; Catalyzes a 2-step react...
#
# [163 rows x 5 columns]

# %%
for i, row in mapping.iterrows():
    query = row["queryItem"]
    target_index = efm_mrna_gc1.var.loc[efm_mrna_gc1.var["protein_name"].str.contains(query)].index
    for i in target_index:
        efm_mrna_gc1.var.loc[i, "string_id"] = row["stringId"]
# Out:
# C:\Users\Jan\AppData\Local\Temp\ipykernel_4948\2353193877.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   target_index = efm_mrna_gc1.var.loc[efm_mrna_gc1.var["protein_name"].str.contains(query)].index

# %%
efm_mrna_gc1.var
# Out:
#                                strains matchin_protein         protein  \
# cds-FCF09_RS09120   GSM5456504_Efm_CDS        no_match        no_match
# cds-WP_001015311.1   GSM5456506_Kp_CDS           match  WP_001015311.1
# cds-WP_002285916.1   GSM5456506_Kp_CDS           match  WP_002285916.1
# cds-WP_002286080.1   GSM5456506_Kp_CDS           match  WP_002286080.1
# cds-WP_002286273.1   GSM5456506_Kp_CDS           match  WP_002286273.1
# ...                                ...             ...             ...
# cds-WP_060806761.1   GSM5456506_Kp_CDS           match  WP_060806761.1
# cds-WP_101699690.1   GSM5456506_Kp_CDS           match  WP_101699690.1
# cds-WP_138821006.1   GSM5456506_Kp_CDS           match  WP_138821006.1
# cds-WP_138821043.1   GSM5456506_Kp_CDS           match  WP_138821043.1
# cds-WP_162166404.1   GSM5456506_Kp_CDS           match  WP_162166404.1
#
#                     n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# cds-FCF09_RS09120                  74     0.015718              98.428207
# cds-WP_001015311.1                 86     0.018692              98.173322
# cds-WP_002285916.1                151     0.034410              96.792693
# cds-WP_002286080.1                 63     0.014019              98.661852
# cds-WP_002286273.1                 63     0.013381              98.661852
# ...                               ...          ...                    ...
# cds-WP_060806761.1                 82     0.017842              98.258284
# cds-WP_101699690.1                 73     0.016355              98.449448
# cds-WP_138821006.1                 68     0.014656              98.555650
# cds-WP_138821043.1                 63     0.013594              98.661852
# cds-WP_162166404.1                214     0.047154              95.454545
#
#                     total_counts  n_cells  \
# cds-FCF09_RS09120           74.0      135
# cds-WP_001015311.1          88.0      119
# cds-WP_002285916.1         162.0      236
# cds-WP_002286080.1          66.0      118
# cds-WP_002286273.1          63.0       97
# ...                          ...      ...
# cds-WP_060806761.1          84.0      128
# cds-WP_101699690.1          77.0      112
# cds-WP_138821006.1          69.0      117
# cds-WP_138821043.1          64.0      101
# cds-WP_162166404.1         222.0      322
#
#                                                          protein_name   rRNA  \
# cds-FCF09_RS09120                                                None  False
# cds-WP_001015311.1  WP_001015311.1 MULTISPECIES: IS6-like element ...  False
# cds-WP_002285916.1  WP_002285916.1 MULTISPECIES: leucine--tRNA lig...  False
# cds-WP_002286080.1  WP_002286080.1 MULTISPECIES: polysaccharide bi...  False
# cds-WP_002286273.1  WP_002286273.1 MULTISPECIES: accessory gene re...  False
# ...                                                               ...    ...
# cds-WP_060806761.1  WP_060806761.1 MULTISPECIES: phospho-sugar mut...  False
# cds-WP_101699690.1  WP_101699690.1 M13-type metalloendopeptidase [...  False
# cds-WP_138821006.1  WP_138821006.1 DNA topoisomerase IV subunit B ...  False
# cds-WP_138821043.1  WP_138821043.1 rod shape-determining protein M...  False
# cds-WP_162166404.1  WP_162166404.1 pyruvate carboxylase [Enterococ...  False
#
#                     ...         PC_lev1         PC_lev2        PC_lev3  \
# cds-FCF09_RS09120   ...        no_match        no_match       no_match
# cds-WP_001015311.1  ...    forDFlev1219    forDFlev2219   forDFlev3219
# cds-WP_002285916.1  ...   forDFlev11003   forDFlev21003  forDFlev31003
# cds-WP_002286080.1  ...    forDFlev1213    forDFlev2213   forDFlev3213
# cds-WP_002286273.1  ...   forDFlev12779   forDFlev22779  forDFlev32779
# ...                 ...             ...             ...            ...
# cds-WP_060806761.1  ...   forDFlev12697   forDFlev22697  forDFlev32697
# cds-WP_101699690.1  ...   forDFlev15363   forDFlev25363  forDFlev35363
# cds-WP_138821006.1  ...    forDFlev1921    forDFlev2921   forDFlev3921
# cds-WP_138821043.1  ...   forDFlev11381   forDFlev21381  forDFlev31381
# cds-WP_162166404.1  ...  lev14totlen720  lev23totlen220    forDFlev320
#
#                           PC_lev4        PC_lev5        PC_lev6  \
# cds-FCF09_RS09120        no_match       no_match       no_match
# cds-WP_001015311.1   forDFlev4219   forDFlev5219   forDFlev6219
# cds-WP_002285916.1  forDFlev41003  forDFlev51003  forDFlev61003
# cds-WP_002286080.1   forDFlev4213   forDFlev5213   forDFlev6213
# cds-WP_002286273.1  forDFlev42779  forDFlev52779  forDFlev62779
# ...                           ...            ...            ...
# cds-WP_060806761.1  forDFlev42697  forDFlev52697  forDFlev62697
# cds-WP_101699690.1  forDFlev45363  forDFlev55363  forDFlev65363
# cds-WP_138821006.1   forDFlev4921   forDFlev5921   forDFlev6921
# cds-WP_138821043.1  forDFlev41381  forDFlev51381  forDFlev61381
# cds-WP_162166404.1    forDFlev420    forDFlev520    forDFlev620
#
#                    log1p_mean_counts  log1p_total_counts  n_counts  \
# cds-FCF09_RS09120           0.015596            4.317488      74.0
# cds-WP_001015311.1          0.018519            4.488636      88.0
# cds-WP_002285916.1          0.033831            5.093750     162.0
# cds-WP_002286080.1          0.013921            4.204693      66.0
# cds-WP_002286273.1          0.013293            4.158883      63.0
# ...                              ...                 ...       ...
# cds-WP_060806761.1          0.017685            4.442651      84.0
# cds-WP_101699690.1          0.016223            4.356709      77.0
# cds-WP_138821006.1          0.014550            4.248495      69.0
# cds-WP_138821043.1          0.013502            4.174387      64.0
# cds-WP_162166404.1          0.046076            5.407172     222.0
#
#                            string_id
# cds-FCF09_RS09120                nan
# cds-WP_001015311.1               nan
# cds-WP_002285916.1  1352.AL014_13845
# cds-WP_002286080.1  1352.AL014_02810
# cds-WP_002286273.1               nan
# ...                              ...
# cds-WP_060806761.1  1352.AL014_02595
# cds-WP_101699690.1               nan
# cds-WP_138821006.1  1352.AL014_04900
# cds-WP_138821043.1  1352.AL014_13475
# cds-WP_162166404.1  1352.AL014_05345
#
# [243 rows x 21 columns]

# %%
interactions = pd.read_csv("../data/string/efm/string_interactions_short_efm.tsv", sep="\t")
interactions
# Out:
#           #node1   node2   node1_string_id   node2_string_id  \
# 0     AOM14739.1   stp_3  1352.AL014_00005  1352.AL014_13450
# 1     AOM14739.1   groEL  1352.AL014_00005  1352.AL014_14690
# 2     AOM14739.1     smc  1352.AL014_00005  1352.AL014_11670
# 3     AOM14739.1  sepF_1  1352.AL014_00005  1352.AL014_08360
# 4     AOM14739.1  ftsA_1  1352.AL014_00005  1352.AL014_08375
# ...          ...     ...               ...               ...
# 1019      thrS_4     tuf  1352.AL014_04055  1352.AL014_04595
# 1020         tig     tuf  1352.AL014_07220  1352.AL014_04595
# 1021         tig  typA_1  1352.AL014_07220  1352.AL014_05325
# 1022        tpiA     zwf  1352.AL014_02215  1352.AL014_08335
# 1023      typA_1    valS  1352.AL014_05325  1352.AL014_01730
#
#       neighborhood_on_chromosome  gene_fusion  phylogenetic_cooccurrence  \
# 0                          0.000          0.0                      0.154
# 1                          0.000          0.0                      0.323
# 2                          0.093          0.0                      0.000
# 3                          0.000          0.0                      0.000
# 4                          0.072          0.0                      0.000
# ...                          ...          ...                        ...
# 1019                       0.046          0.0                      0.000
# 1020                       0.093          0.0                      0.000
# 1021                       0.069          0.0                      0.000
# 1022                       0.000          0.0                      0.000
# 1023                       0.055          0.0                      0.000
#
#       homology  coexpression  experimentally_determined_interaction  \
# 0          0.0         0.324                                  0.000
# 1          0.0         0.000                                  0.000
# 2          0.0         0.148                                  0.237
# 3          0.0         0.401                                  0.000
# 4          0.0         0.378                                  0.000
# ...        ...           ...                                    ...
# 1019       0.0         0.142                                  0.381
# 1020       0.0         0.480                                  0.000
# 1021       0.0         0.442                                  0.000
# 1022       0.0         0.088                                  0.000
# 1023       0.0         0.315                                  0.000
#
#       database_annotated  automated_textmining  combined_score
# 0                  0.000                 0.000           0.403
# 1                  0.000                 0.159           0.406
# 2                  0.000                 0.192           0.459
# 3                  0.000                 0.165           0.478
# 4                  0.000                 0.191           0.492
# ...                  ...                   ...             ...
# 1019               0.074                 0.194           0.552
# 1020               0.000                 0.194           0.586
# 1021               0.000                 0.267           0.585
# 1022               0.800                 0.278           0.856
# 1023               0.000                 0.190           0.429
#
# [1024 rows x 13 columns]

# %%
n = efm_mrna_gc1.shape[1]
non_zero_entries = np.count_nonzero(efm_sol_gc1)
num_reported_interactions = 0

for i in range(n):
    for j in range(i+1, n):
        if efm_sol_gc1[i, j] != 0:
            a = efm_mrna_gc1.var.iloc[i]["string_id"]
            b = efm_mrna_gc1.var.iloc[j]["string_id"]
            
            interaction = interactions.loc[(interactions["node1_string_id"] == a) & (interactions["node2_string_id"] == b)]["combined_score"]
            if len(interaction) > 0:
                for k in range(len(interaction)):
                    print(f"{efm_mrna_gc1.var.iloc[i]['protein_name']} - {efm_mrna_gc1.var.iloc[j]['protein_name']}: {interaction.values[k]}")
                    num_reported_interactions += 1
# Out:
# WP_002286629.1 MULTISPECIES: cell division protein FtsZ [Enterococcus] - WP_002288500.1 MULTISPECIES: transcription termination factor NusA [Enterococcus]: 0.405
# WP_002286629.1 MULTISPECIES: cell division protein FtsZ [Enterococcus] - WP_002289606.1 MULTISPECIES: PBP1A family penicillin-binding protein [Enterococcus]: 0.411
# WP_002286629.1 MULTISPECIES: cell division protein FtsZ [Enterococcus] - WP_002290442.1 MULTISPECIES: elongation factor Tu [Enterococcus]: 0.532
# WP_002286629.1 MULTISPECIES: cell division protein FtsZ [Enterococcus] - WP_002290607.1 MULTISPECIES: chaperonin GroEL [Enterococcus]: 0.495
# WP_002286629.1 MULTISPECIES: cell division protein FtsZ [Enterococcus] - WP_002321575.1 MULTISPECIES: DNA gyrase subunit A [Enterococcus]: 0.723
# WP_002287403.1 MULTISPECIES: transcription-repair coupling factor [Enterococcus] - WP_002289722.1 MULTISPECIES: ATP-dependent DNA helicase RecG [Enterococcus]: 0.475
# WP_002287612.1 MULTISPECIES: beta-ketoacyl-ACP synthase III [Enterococcus] - WP_002288688.1 MULTISPECIES: preprotein translocase subunit SecY [Enterococcus]: 0.544
# WP_002288500.1 MULTISPECIES: transcription termination factor NusA [Enterococcus] - WP_002290442.1 MULTISPECIES: elongation factor Tu [Enterococcus]: 0.621
# WP_002288688.1 MULTISPECIES: preprotein translocase subunit SecY [Enterococcus] - WP_002290442.1 MULTISPECIES: elongation factor Tu [Enterococcus]: 0.596
# WP_002288695.1 MULTISPECIES: translation initiation factor IF-1 [Enterococcus] - WP_002290442.1 MULTISPECIES: elongation factor Tu [Enterococcus]: 0.673
# WP_002289497.1 MULTISPECIES: DNA primase [Enterococcus] - WP_002294984.1 MULTISPECIES: preprotein translocase subunit SecA [Enterococcus]: 0.661
# WP_002289497.1 MULTISPECIES: DNA primase [Enterococcus] - WP_002296525.1 MULTISPECIES: nucleotide exchange factor GrpE [Enterococcus]: 0.593
# WP_002292812.1 MULTISPECIES: phosphopyruvate hydratase [Enterococcus] - WP_002295135.1 MULTISPECIES: phosphoglycerate kinase [Enterococcus]: 0.999

# %%
num_reported_interactions
# Out:
# 13

# %%
non_zero_entries
# Out:
# 1169

# %%
num_reported_interactions / non_zero_entries
# Out:
# 0.011120615911035072
